# %%
LoadPackage("YDCatOverkG", "0", false);
# Out:
# true

# %%
?IrreducibleRepresentations
# Out:
# Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap71.html#X7F29C5447B5DC102">IrreducibleRepresentations</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap71.html#X8493ED7A86FFCB8A">IrreducibleRepresentationsDixon</a><br/>
