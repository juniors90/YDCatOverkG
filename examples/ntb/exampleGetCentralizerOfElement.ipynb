# %%
LoadPackage("YDCatOverkG", "0", false);
# Out:
# true

# %%
G:=SymmetricGroup(3);
# Out:
# Sym( [ 1 .. 3 ] )

# %%
repsCC := List(ConjugacyClasses(G), Representative);
# Out:
# [ (), (1,2), (1,2,3) ]

# %%
G_e := GetCentralizerOfElement(G, repsCC[1] );
# Out:
# rec( G := SymmetricGroup( [ 1 .. 3 ] ), centralizer := Group( [ (1,3), (2,3) ] ), centralizerSize := 6, classSize := 1, g := (), structure := "S3" )

# %%
SimplesModByCentralizer(G_e);
# Out:
# [ <Simple D(G)-Module with Weight ( () , rho )>,   <Simple D(G)-Module with Weight ( () , rho )>,   <Simple D(G)-Module with Weight ( () , rho )> ]
