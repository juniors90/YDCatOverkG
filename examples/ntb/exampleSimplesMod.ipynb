# %%
LoadPackage("YDCatOverkG", "0", false);
# Out:
# true

# %%
G:=SymmetricGroup(3);
# Out:
# Sym( [ 1 .. 3 ] )

# %%
all_simples := SimplesMod( G );
# Out:
# [ <Simple D(G)-Module with Weight ( () , rho )>,   <Simple D(G)-Module with Weight ( () , rho )>,   <Simple D(G)-Module with Weight ( () , rho )>,   <Simple D(G)-Module with Weight ( (1,2) , rho )>,   <Simple D(G)-Module with Weight ( (1,2) , rho )>,   <Simple D(G)-Module with Weight ( (1,2,3) , rho )>,   <Simple D(G)-Module with Weight ( (1,2,3) , rho )>,   <Simple D(G)-Module with Weight ( (1,2,3) , rho )> ]

# %%
dim_drinfelf_double_of_G := Order(G)^2; # dim(D(H))
sum_squares_of_M_g_rho := Sum(List(all_simples, x -> Length(Base(x))^2));
dim_drinfelf_double_of_G = sum_squares_of_M_g_rho;
# Out:
# 36
# 36
# true
