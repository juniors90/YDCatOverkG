# %%
LoadPackage("YDCatOverkG", "0", false);
# Out:
# true

# %%
G:=SymmetricGroup(3);
# Out:
# Sym( [ 1 .. 3 ] )

# %%
repCC:= List(ConjugacyClasses(G), Representative);
# Out:
# [ (), (1,2), (1,2,3) ]

# %%
simples_attached_to_e := SimplesModAttachedToElement( G, repCC[1] );
# Out:
# [ <Simple D(G)-Module with Weight ( () , rho )>,   <Simple D(G)-Module with Weight ( () , rho )>,   <Simple D(G)-Module with Weight ( () , rho )> ]

# %%
simples_attached_to_12 := SimplesModAttachedToElement( G, repCC[2] );
# Out:
# [ <Simple D(G)-Module with Weight ( (1,2) , rho )>,   <Simple D(G)-Module with Weight ( (1,2) , rho )> ]

# %%
simples_attached_to_12 := SimplesModAttachedToElement( G, repCC[2] );
# Out:
# [ <Simple D(G)-Module with Weight ( (1,2) , rho )>,   <Simple D(G)-Module with Weight ( (1,2) , rho )> ]
